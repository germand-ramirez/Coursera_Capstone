# %% [markdown]
# # Configuration

# %%
# Data Science
import pandas as pd
import numpy as np

# utils
import time

# %%
# This package is deployed in google colab, and use the below versions:
for package in [pd, np]:
  print(f'{package.__name__}: {package.__version__}')
# Out:
# pandas: 1.1.2
# numpy: 1.18.5

# %% [markdown]
# # Objetive

# %%
for i in range(1):
  _ = i * ' '
  print(f'/\\{_}>>Hello Capstone Project Course!>>', end='>>')
  time.sleep(0.4)
# Out:
# /\>>Hello Capstone Project Course!>>>>

# %%
print('Hola', end='\r')
# Out:
# Hola
